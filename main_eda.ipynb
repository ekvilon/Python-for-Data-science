# %%
from pathlib import Path

import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from eda import Eda

# %%
DATA_DIR = Path('./data')
TRAIN_FILE = DATA_DIR / 'train.csv'
TEST_FILE = DATA_DIR / 'test.csv'
TARGET_FEATURE = 'Credit Default'

# %%
train_df = pd.read_csv(TRAIN_FILE)
test_df = pd.read_csv(TEST_FILE)
base_features = train_df.columns.drop(TARGET_FEATURE).tolist()

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Home Ownership                7500 non-null   object
#  1   Annual Income                 5943 non-null   float64
#  2   Years in current job          7129 non-null   object
#  3   Tax Liens                     7500 non-null   float64
#  4   Number of Open Accounts       7500 non-null   float64
#  5   Years of Credit History       7500 non-null   float64
#  6   Maximum Open Credit           7500 non-null   float64
#  7   Number of Credit Problems     7500 non-null   float64
#  8   Months since last delinquent  3419 non-null   float64
#  9   Bankruptcies                  7486 non-null   float64
#  10  Purpose                       7500 non-null   object
#  11  Term                          7500 non-null   object
# ...

# %%
train_df.head()
# Out:
#   Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0       Own Home       482087.0                  NaN        0.0
# 1       Own Home      1025487.0            10+ years        0.0
# 2  Home Mortgage       751412.0              8 years        0.0
# 3       Own Home       805068.0              6 years        0.0
# 4           Rent       776264.0              8 years        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                     11.0                     26.3             685960.0
# 1                     15.0                     15.3            1181730.0
# 2                     11.0                     35.0            1182434.0
# 3                      8.0                     22.5             147400.0
# 4                     13.0                     13.6             385836.0
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# ...

# %%
corr_with_target = train_df[base_features + [TARGET_FEATURE]].corr().iloc[:-1, -1].sort_values(ascending=False)

plt.figure(figsize=(10, 8))

sns.barplot(x=corr_with_target.values, y=corr_with_target.index)

plt.title('Correlation with target variable')
plt.show()

# %%
eda = Eda()

# %% [markdown]
# ### EDA: Home Ownership

# %%
eda.perform_for_categorical_feature(train_df, test_df, 'Home Ownership', 'Credit Default')
# Out:
#        Home Ownership
# count            7500
# unique              4
# top     Home Mortgage
# freq             3637
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Home Ownership  7500 non-null   object
# dtypes: object(1)
# memory usage: 58.7+ KB
# None
# 'Total NA: 0, has coverage: 0.0%'

# %% [markdown]
# ### EDA: Annual Income

# %%
eda.perform_for_numerical_feature(train_df, test_df, 'Annual Income', 'Credit Default')
# Out:
#        Annual Income
# count   5.943000e+03
# mean    1.366392e+06
# std     8.453392e+05
# min     1.645970e+05
# 25%     8.443410e+05
# 50%     1.168386e+06
# 75%     1.640137e+06
# max     1.014934e+07
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Annual Income  5943 non-null   float64
# dtypes: float64(1)
# memory usage: 58.7 KB
# MannwhitneyuResult(statistic=9362155.5, pvalue=0.45908193952511717)
# None
# 'Total NA: 1557, has coverage: 20.76%'

# %% [markdown]
# ### EDA: Years in current job

# %%
eda.perform_for_categorical_feature(train_df, test_df, 'Years in current job', 'Credit Default')
# Out:
#        Years in current job
# count                  7129
# unique                   11
# top               10+ years
# freq                   2332
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Years in current job  7129 non-null   object
# dtypes: object(1)
# memory usage: 58.7+ KB
# None
# 'Total NA: 371, has coverage: 4.946666666666666%'

# %% [markdown]
# ### EDA: Tax Liens

# %%
eda.perform_for_numerical_feature(train_df, test_df, 'Tax Liens', 'Credit Default')
# Out:
#          Tax Liens
# count  7500.000000
# mean      0.030133
# std       0.271604
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       7.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Tax Liens  7500 non-null   float64
# dtypes: float64(1)
# memory usage: 58.7 KB
# MannwhitneyuResult(statistic=9336937.5, pvalue=0.09836860283803656)
# None
# 'Total NA: 0, has coverage: 0.0%'

# %% [markdown]
# ### EDA: Number of Open Accounts

# %%
eda.perform_for_numerical_feature(train_df, test_df, 'Number of Open Accounts', 'Credit Default')
# Out:
#        Number of Open Accounts
# count              7500.000000
# mean                 11.130933
# std                   4.908924
# min                   2.000000
# 25%                   8.000000
# 50%                  10.000000
# 75%                  14.000000
# max                  43.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Number of Open Accounts  7500 non-null   float64
# dtypes: float64(1)
# memory usage: 58.7 KB
# MannwhitneyuResult(statistic=9279311.5, pvalue=0.22142637178864455)
# None
# 'Total NA: 0, has coverage: 0.0%'

# %% [markdown]
# ### EDA: Years of Credit History

# %%
eda.perform_for_numerical_feature(train_df, test_df, 'Years of Credit History', 'Credit Default')
# Out:
#        Years of Credit History
# count              7500.000000
# mean                 18.317467
# std                   7.041946
# min                   4.000000
# 25%                  13.500000
# 50%                  17.000000
# 75%                  21.800000
# max                  57.700000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Years of Credit History  7500 non-null   float64
# dtypes: float64(1)
# memory usage: 58.7 KB
# MannwhitneyuResult(statistic=9339658.0, pvalue=0.3886945952485082)
# None
# 'Total NA: 0, has coverage: 0.0%'

# %% [markdown]
# ### EDA: Maximum Open Credit

# %%
eda.perform_for_numerical_feature(train_df, test_df, 'Maximum Open Credit', 'Credit Default')
# Out:
#        Maximum Open Credit
# count         7.500000e+03
# mean          9.451537e+05
# std           1.602622e+07
# min           0.000000e+00
# 25%           2.792295e+05
# 50%           4.781590e+05
# 75%           7.935015e+05
# max           1.304726e+09
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Maximum Open Credit  7500 non-null   float64
# dtypes: float64(1)
# memory usage: 58.7 KB
# MannwhitneyuResult(statistic=9337869.0, pvalue=0.3832220993414893)
# None
# 'Total NA: 0, has coverage: 0.0%'

# %% [markdown]
# ### EDA: Number of Credit Problems

# %%
eda.perform_for_numerical_feature(train_df, test_df, 'Number of Credit Problems', 'Credit Default')
# Out:
#        Number of Credit Problems
# count                7500.000000
# mean                    0.170000
# std                     0.498598
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                     7.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Number of Credit Problems  7500 non-null   float64
# dtypes: float64(1)
# memory usage: 58.7 KB
# MannwhitneyuResult(statistic=9295513.5, pvalue=0.14195772552376257)
# None
# 'Total NA: 0, has coverage: 0.0%'

# %% [markdown]
# ### EDA: Months since last delinquent

# %% [markdown]
# Has low correlation with the target, it is a good candidate to be removed.

# %% [markdown]
# ### EDA: Bankruptcies

# %% [markdown]
# Has low correlation with the target, it is a good candidate to be removed.

# %% [markdown]
# ### EDA: Purpose

# %%
eda.perform_for_categorical_feature(train_df, test_df, 'Purpose', 'Credit Default')
# Out:
#                    Purpose
# count                 7500
# unique                  15
# top     debt consolidation
# freq                  5944
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Purpose  7500 non-null   object
# dtypes: object(1)
# memory usage: 58.7+ KB
# None
# 'Total NA: 0, has coverage: 0.0%'

# %% [markdown]
# ### EDA: Term

# %%
eda.perform_for_categorical_feature(train_df, test_df, 'Term', 'Credit Default')
# Out:
#               Term
# count         7500
# unique           2
# top     Short Term
# freq          5556
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Term    7500 non-null   object
# dtypes: object(1)
# memory usage: 58.7+ KB
# None
# 'Total NA: 0, has coverage: 0.0%'

# %% [markdown]
# ### EDA: Current Loan Amount

# %%
eda.perform_for_numerical_feature(train_df, test_df, 'Current Loan Amount', 'Credit Default')
# Out:
# Current Loan Amount
# 309573.0               870
# 89298.0                  6
# 218064.0                 6
# 270226.0                 5
# 216106.0                 5
#                       ...
# 353650.0                 1
# 353694.0                 1
# 353716.0                 1
# 353936.0                 1
# 11242.0                  1
# Length: 5386, dtype: int64

# %% [markdown]
# ### EDA: Current Credit Balance

# %%
eda.perform_for_numerical_feature(train_df, test_df, 'Current Credit Balance', 'Credit Default')
# Out:
#        Current Credit Balance
# count            7.500000e+03
# mean             2.898332e+05
# std              3.178714e+05
# min              0.000000e+00
# 25%              1.142565e+05
# 50%              2.093230e+05
# 75%              3.604062e+05
# max              6.506797e+06
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Current Credit Balance  7500 non-null   float64
# dtypes: float64(1)
# memory usage: 58.7 KB
# MannwhitneyuResult(statistic=9334050.0, pvalue=0.3716147491364306)
# None
# 'Total NA: 0, has coverage: 0.0%'

# %% [markdown]
# ### EDA: Monthly Debt

# %%
eda.perform_for_numerical_feature(train_df, test_df, 'Monthly Debt', 'Credit Default')
# Out:
#         Monthly Debt
# count    7500.000000
# mean    18314.454133
# std     11926.764673
# min         0.000000
# 25%     10067.500000
# 50%     16076.500000
# 75%     23818.000000
# max    136679.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Monthly Debt  7500 non-null   float64
# dtypes: float64(1)
# memory usage: 58.7 KB
# MannwhitneyuResult(statistic=9288187.0, pvalue=0.24369523330673137)
# None
# 'Total NA: 0, has coverage: 0.0%'

# %% [markdown]
# ### EDA: Credit Score

# %%
eda.perform_for_numerical_feature(train_df, test_df, 'Credit Score', 'Credit Default')
# Out:
#        Credit Score
# count   5943.000000
# mean    1151.087498
# std     1604.451418
# min      585.000000
# 25%      711.000000
# 50%      731.000000
# 75%      743.000000
# max     7510.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Credit Score  5943 non-null   float64
# dtypes: float64(1)
# memory usage: 58.7 KB
# MannwhitneyuResult(statistic=9359581.5, pvalue=0.45091647518794764)
# None
# 'Total NA: 1557, has coverage: 20.76%'
